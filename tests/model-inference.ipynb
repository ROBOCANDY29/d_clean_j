# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
import pandas as pd
import torch

# %%
model = AutoModelForCausalLM.from_pretrained("/mnt/d/indus-finetuned-datasets/Inference-model-weights",torch_dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained("/mnt/d/indus-finetuned-datasets/Inference-model-weights")

# %%
#model.save_pretrained("/mnt/d/indus-finetuned-datasets/Inference-model-weights/16-bit-model")
#tokenizer.save_pretrained("/mnt/d/indus-finetuned-datasets/Inference-model-weights/16-bit-model")
# Out:
# ('/mnt/d/indus-finetuned-datasets/Inference-model-weights/16-bit-model/tokenizer_config.json',
#  '/mnt/d/indus-finetuned-datasets/Inference-model-weights/16-bit-model/special_tokens_map.json',
#  '/mnt/d/indus-finetuned-datasets/Inference-model-weights/16-bit-model/tokenizer.json')

# %%
#model.push_to_hub("makers-lab/Indus-1.1B-IT2.0")
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/makers-lab/Indus-1.1B-IT2.0/commit/2abd209d4d97d31ca04a3155f26e7214ed02955f', commit_message='Upload model', commit_description='', oid='2abd209d4d97d31ca04a3155f26e7214ed02955f', pr_url=None, pr_revision=None, pr_num=None)

# %%
#tokenizer.push_to_hub("makers-lab/Indus-1.1B-IT2.0")
# Out:
# CommitInfo(commit_url='https://huggingface.co/makers-lab/Indus-1.1B-IT2.0/commit/388a9846bbf61dc823b526bca6c1e4e654908bcf', commit_message='Upload tokenizer', commit_description='', oid='388a9846bbf61dc823b526bca6c1e4e654908bcf', pr_url=None, pr_revision=None, pr_num=None)

# %%
#model.save_pretrained("/mnt/d/indus-finetuned-datasets/hugging-face-model-weights")

# %%
#tokenizer.save_pretrained("/mnt/d/indus-finetuned-datasets/hugging-face-model-weights")
# Out:
# ('/mnt/d/indus-finetuned-datasets/hugging-face-model-weights/tokenizer_config.json',
#  '/mnt/d/indus-finetuned-datasets/hugging-face-model-weights/special_tokens_map.json',
#  '/mnt/d/indus-finetuned-datasets/hugging-face-model-weights/tokenizer.json')

# %%
# Example inference
def format_template(user_prompt):
    messages = [
        {"role": "user", "content": user_prompt},
    ]
    response = tokenizer.apply_chat_template(messages, tokenize=True,  add_generation_prompt=True, return_tensors="pt")
    return  response

user_prompt = """भारत के वर्तमान प्रधानमंत्री कौन हैं?"""

input_ids = format_template(user_prompt)

# Generate text using the model
output = model.generate(input_ids,
                        eos_token_id=tokenizer.eos_token_id,
                        pad_token_id=tokenizer.eos_token_id,
                        max_length=1024,
                        num_beams=5,
                        do_sample=True,
                        early_stopping=True,
                        temperature=0.7,
                        top_k=50,
                        top_p=0.95,
                        repetition_penalty=1.2,
                        no_repeat_ngram_size=3,
                        num_return_sequences=1,
                        )
print(tokenizer.decode(output[0], skip_special_tokens=False))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 14
#      11 input_ids = format_template(user_prompt)
#      13 # Generate text using the model
# ---> 14 output = model.generate(input_ids,
#      15                         eos_token_id=tokenizer.eos_token_id,
#      16                         pad_token_id=tokenizer.eos_token_id,
#      17                         max_length=1024,
#      18                         num_beams=5,
#      19                         do_sample=True,
#      20                         early_stopping=True,
#      21                         temperature=0.7,
#      22                         top_k=50,
#      23                         top_p=0.95,
#      24                         repetition_penalty=1.2,
#      25                         no_repeat_ngram_size=3,
#      26                         num_return_sequences=1,
#      27                         )
#      28 print(tokenizer.decode(output[0], skip_special_tokens=False))
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/generation/utils.py:2063, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2055     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2056         input_ids=input_ids,
#    2057         expand_size=generation_config.num_beams,
#    2058         is_encoder_decoder=self.config.is_encoder_decoder,
#    2059         **model_kwargs,
#    2060     )
#    2062     # 14. run beam sample
# -> 2063     result = self._beam_search(
#    2064         input_ids,
#    2065         beam_scorer,
#    2066         logits_processor=prepared_logits_processor,
#    2067         logits_warper=prepared_logits_warper,
#    2068         stopping_criteria=prepared_stopping_criteria,
#    2069         generation_config=generation_config,
#    2070         synced_gpus=synced_gpus,
#    2071         **model_kwargs,
#    2072     )
#    2074 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2075     # 11. prepare beam search scorer
#    2076     beam_scorer = BeamSearchScorer(
#    2077         batch_size=batch_size,
#    2078         num_beams=generation_config.num_beams,
#    (...)
#    2084         max_length=generation_config.max_length,
#    2085     )
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/generation/utils.py:3238, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, logits_warper, **model_kwargs)
#    3235     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3237 else:  # Unchanged original behavior
# -> 3238     outputs = self(**model_inputs, return_dict=True)
#    3240 if synced_gpus and this_peer_finished:
#    3241     cur_len = cur_len + 1
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1315, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1307 r"""
#    1308 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1309     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1310     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1311     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1312 """
#    1313 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1315 transformer_outputs = self.transformer(
#    1316     input_ids,
#    1317     past_key_values=past_key_values,
#    1318     attention_mask=attention_mask,
#    1319     token_type_ids=token_type_ids,
#    1320     position_ids=position_ids,
#    1321     head_mask=head_mask,
#    1322     inputs_embeds=inputs_embeds,
#    1323     encoder_hidden_states=encoder_hidden_states,
#    1324     encoder_attention_mask=encoder_attention_mask,
#    1325     use_cache=use_cache,
#    1326     output_attentions=output_attentions,
#    1327     output_hidden_states=output_hidden_states,
#    1328     return_dict=return_dict,
#    1329 )
#    1330 hidden_states = transformer_outputs[0]
#    1332 # Set device for model parallelism
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1129, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#    1117     outputs = self._gradient_checkpointing_func(
#    1118         block.__call__,
#    1119         hidden_states,
#    (...)
#    1126         output_attentions,
#    1127     )
#    1128 else:
# -> 1129     outputs = block(
#    1130         hidden_states,
#    1131         layer_past=layer_past,
#    1132         attention_mask=attention_mask,
#    1133         head_mask=head_mask[i],
#    1134         encoder_hidden_states=encoder_hidden_states,
#    1135         encoder_attention_mask=encoder_attention_mask,
#    1136         use_cache=use_cache,
#    1137         output_attentions=output_attentions,
#    1138     )
#    1140 hidden_states = outputs[0]
#    1141 if use_cache is True:
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:614, in GPT2Block.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     612 residual = hidden_states
#     613 hidden_states = self.ln_1(hidden_states)
# --> 614 attn_outputs = self.attn(
#     615     hidden_states,
#     616     layer_past=layer_past,
#     617     attention_mask=attention_mask,
#     618     head_mask=head_mask,
#     619     use_cache=use_cache,
#     620     output_attentions=output_attentions,
#     621 )
#     622 attn_output = attn_outputs[0]  # output_attn: a, present, (attentions)
#     623 outputs = attn_outputs[1:]
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:517, in GPT2SdpaAttention.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     515     attention_mask = encoder_attention_mask
#     516 else:
# --> 517     query, key, value = self.c_attn(hidden_states).split(self.split_size, dim=2)
#     519 query = self._split_heads(query, self.num_heads, self.head_dim)
#     520 key = self._split_heads(key, self.num_heads, self.head_dim)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /mnt/d/python-projects/IndusNLPToolkit/kit/lib/python3.10/site-packages/transformers/pytorch_utils.py:105, in Conv1D.forward(self, x)
#     103 def forward(self, x):
#     104     size_out = x.size()[:-1] + (self.nf,)
# --> 105     x = torch.addmm(self.bias, x.view(-1, x.size(-1)), self.weight)
#     106     x = x.view(size_out)
#     107     return x
#
# KeyboardInterrupt:

# %%
# Load the Excel file
df = pd.read_excel('/mnt/d/indus-finetuned-datasets/testing-indus/Indus_Testing_Prompts_V2.xlsx')
print(df)
# Out:
#                                                Prompt
# 0                       सम्राट अशोक के बारे में बताओ।
# 1                                  गौतम बुद्ध कौन थे?
# 2                महाभारत में कृष्ण की क्या भूमिका है?
# 3   वार्षिक पुष्कर मेला किस राज्य में आयोजित किया ...
# 4                          मुझे रामायण की कहानी बताओ।
# ..                                                ...
# 70  भारत में राष्ट्रीय उपभोक्ता दिवस प्रतिवर्ष किस...
# 71         भारत में अंतरराष्ट्रीय सौर गठबंधन क्या है?
# 72                     पराक्रम दिवस का क्या महत्व है?
# 73  नए दिशानिर्देशों के अनुसार कोचिंग सेंटरों में ...
# 74  विकसित भारत संकल्प यात्रा का प्राथमिक उद्देश्य...
#
# [75 rows x 1 columns]

# %%
# Testing the responses from excel file



# Load the Excel file
df = pd.read_excel('/mnt/d/indus-finetuned-datasets/testing-indus/Indus_Testing_Prompts_V2.xlsx')


# Example inference
def format_template(user_prompt):
    messages = [
        {"role": "user", "content": user_prompt},
    ]
    response = tokenizer.apply_chat_template(messages, tokenize=True,  add_generation_prompt=True, return_tensors="pt")
    return  response



# Define a function that formats the prompt and generates a response
def generate_response(user_prompt):
    # Format the input prompt
    input_ids = format_template(user_prompt)
    
    # Generate text using the model
    output = model.generate(input_ids,
                            eos_token_id=tokenizer.eos_token_id,
                            pad_token_id=tokenizer.eos_token_id,
                            max_length=1024,
                            num_beams=5,
                            do_sample=True,
                            early_stopping=True,
                            temperature=0.7,
                            top_k=50,
                            top_p=0.95,
                            repetition_penalty=1.2,
                            no_repeat_ngram_size=3,
                            num_return_sequences=1,
                            )
    
    # Decode the generated output
    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)
    print(decoded_output)
    
    return decoded_output

# Apply the function to each row in the 'prompts' column
df['Response'] = df['Prompt'].apply(generate_response)

# %%
# Save the DataFrame to a new Excel file
df.to_excel('/mnt/d/indus-finetuned-datasets/testing-indus/Indus_Testing_Prompts_V2_Response.xlsx', index=False)
